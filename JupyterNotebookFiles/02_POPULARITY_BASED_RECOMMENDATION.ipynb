# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING DATA

# %%
a = pd.read_csv('1950-1989/bollywood_1950-1989.csv')

# %%
a
# Out:
#                              title    imdb_id  \
# 0                      Aag Ka Gola  tt0177489
# 1                       Ram Lakhan  tt0098168
# 2                 Asmaan Se Ooncha  tt0233146
# 3                           Tridev  tt0100816
# 4                        ChaalBaaz  tt0122427
# ...                            ...        ...
# 2209  Hindustan Hamara (1950 film)  tt0273261
# 2210      Sheesh Mahal (1950 film)  tt0243555
# 2211           Meena Bazaar (film)  tt0213081
# 2212                  Sati Narmada  tt0230735
# 2213          Ek Musafir Ek Hasina  tt0055949
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/2/2a...
# 1     https://upload.wikimedia.org/wikipedia/en/thum...
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4     https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
c = pd.read_csv('1950-1989/bollywood_ratings_1950-1989.csv')

# %%
c
# Out:
#         imdb_id  imdb_rating  imdb_votes
# 0     tt0177489          5.4          81
# 1     tt0098168          6.8        1993
# 2     tt0233146          5.0          44
# 3     tt0100816          6.3        1602
# 4     tt0122427          6.7        1298
# ...         ...          ...         ...
# 1904  tt0244182          6.2          20
# 1905  tt0269826          6.8          21
# 1906  tt0243555          7.0          13
# 1907  tt0213081          7.0           9
# 1908  tt0055949          6.7          39
#
# [1909 rows x 3 columns]

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1909 entries, 0 to 1908
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      1909 non-null   object
#  1   imdb_rating  1909 non-null   float64
#  2   imdb_votes   1909 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 44.9+ KB

# %%
a1 = pd.read_csv('1950-1989/bollywood_1950-1989.csv')
b1 = pd.read_csv('1950-1989/bollywood_ratings_1950-1989.csv')

a2 = pd.read_csv('1990-2009/bollywood_1990-2009.csv')
b2 = pd.read_csv('1990-2009/bollywood_ratings_1990-2009.csv')

a3 = pd.read_csv('2010-2019/bollywood_2010-2019.csv')
b3 = pd.read_csv('2010-2019/bollywood_ratings_2010-2019.csv')

# %%
a1.dropna(subset =['imdb_id'],axis=0, inplace=True)

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2161 entries, 0 to 2213
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        2161 non-null   object
#  1   imdb_id      2161 non-null   object
#  2   poster_path  1508 non-null   object
#  3   wiki_link    2161 non-null   object
# dtypes: object(4)
# memory usage: 84.4+ KB

# %%
b1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1909 entries, 0 to 1908
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      1909 non-null   object
#  1   imdb_rating  1909 non-null   float64
#  2   imdb_votes   1909 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 44.9+ KB

# %%
a1[a1.duplicated('imdb_id', keep=False)]
# Out:
#                          title    imdb_id  \
# 23        Chingari (1989 film)  tt0172509
# 27           Goonj (1989 film)  tt0172509
# 680   Arising from the Surface  tt0081453
# 723   Arising from the Surface  tt0081453
# 1492        Aya Sawan Jhoom Ke  tt0229950
# ...                        ...        ...
# 2149                       Aan  tt0044318
# 2150                   Sangdil  tt0130991
# 2153                       Aan  tt0044318
# 2162                   Sangdil  tt0130991
# 2213      Ek Musafir Ek Hasina  tt0055949
#
#                                             poster_path  \
# 23                                                  NaN
# 27    https://upload.wikimedia.org/wikipedia/en/d/d3...
# 680                                                 NaN
# 723                                                 NaN
# 1492  https://upload.wikimedia.org/wikipedia/en/e/ef...
# ...                                                 ...
# 2149  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
a1.drop_duplicates(subset=['imdb_id'], inplace=True)

# %%
b1[b1.duplicated('imdb_id', keep=False)]
# Out:
#         imdb_id  imdb_rating  imdb_votes
# 19    tt0172509          6.0          37
# 23    tt0172509          6.0          37
# 624   tt0081453          6.8          58
# 665   tt0081453          6.8          58
# 1334  tt0229950          6.7          92
# ...         ...          ...         ...
# 1864  tt0044318          7.1         228
# 1865  tt0130991          7.4          73
# 1867  tt0044318          7.1         228
# 1874  tt0130991          7.4          73
# 1908  tt0055949          6.7          39
#
# [66 rows x 3 columns]

# %%
b1.drop_duplicates(subset=['imdb_id'], inplace=True)

# %%
x = a1.merge(b1, on='imdb_id')

# %%
x
# Out:
#                          title    imdb_id  \
# 0                  Aag Ka Gola  tt0177489
# 1                   Ram Lakhan  tt0098168
# 2             Asmaan Se Ooncha  tt0233146
# 3                       Tridev  tt0100816
# 4                    ChaalBaaz  tt0122427
# ...                        ...        ...
# 1871       Samadhi (1950 film)  tt0268614
# 1872       Sangram (1950 film)  tt0244182
# 1873        Sargam (1950 film)  tt0269826
# 1874  Sheesh Mahal (1950 film)  tt0243555
# 1875       Meena Bazaar (film)  tt0213081
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/2/2a...
# 1     https://upload.wikimedia.org/wikipedia/en/thum...
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4     https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1871  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
a2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1598 entries, 0 to 1597
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        1598 non-null   object
#  1   imdb_id      1538 non-null   object
#  2   poster_path  1297 non-null   object
#  3   wiki_link    1598 non-null   object
# dtypes: object(4)
# memory usage: 50.1+ KB

# %%
a2.duplicated('imdb_id').sum()
# Out:
# 66

# %%
a2.drop_duplicates('imdb_id', inplace=True)

# %%
b2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      1508 non-null   object
#  1   imdb_rating  1508 non-null   float64
#  2   imdb_votes   1508 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 35.5+ KB

# %%
b2.duplicated('imdb_id').sum()
# Out:
# 7

# %%
b2.drop_duplicates('imdb_id', inplace=True)

# %%
y = a2.merge(b2, on='imdb_id')

# %%
a3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        980 non-null    object
#  1   imdb_id      935 non-null    object
#  2   poster_path  920 non-null    object
#  3   wiki_link    980 non-null    object
# dtypes: object(4)
# memory usage: 30.8+ KB

# %%
a3.duplicated('imdb_id').sum()
# Out:
# 47

# %%
a3.drop_duplicates('imdb_id', inplace=True)

# %%
a3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 933 entries, 0 to 979
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        933 non-null    object
#  1   imdb_id      932 non-null    object
#  2   poster_path  888 non-null    object
#  3   wiki_link    933 non-null    object
# dtypes: object(4)
# memory usage: 36.4+ KB

# %%
a3.dropna(subset=['imdb_id'], inplace=True)

# %%
b3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      935 non-null    object
#  1   imdb_rating  922 non-null    float64
#  2   imdb_votes   922 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 22.0+ KB

# %%
b3.duplicated('imdb_id').sum()
# Out:
# 3

# %%
b3.drop_duplicates('imdb_id', inplace=True)

# %%
b3.duplicated('imdb_id').sum()
# Out:
# 0

# %%
b3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 932 entries, 0 to 934
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdb_id      932 non-null    object
#  1   imdb_rating  919 non-null    float64
#  2   imdb_votes   919 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 29.1+ KB

# %%
z = a3.merge(b3, on='imdb_id')

# %%
z
# Out:
#                                     title    imdb_id  \
# 0                Uri: The Surgical Strike  tt8291224
# 1                           Rangeela Raja  tt9052964
# 2                           Battalion 609  tt9472208
# 3    The Accidental Prime Minister (film)  tt6986710
# 4                         Why Cheat India  tt8108208
# ..                                    ...        ...
# 927                        Dulha Mil Gaya  tt1182884
# 928                       Anjaana Anjaani  tt1499201
# 929              Dunno Y... Na Jaane Kyon  tt1742307
# 930                                 Pankh  tt1124386
# 931                        Action Replayy  tt1396208
#
#                                            poster_path  \
# 0    https://upload.wikimedia.org/wikipedia/en/thum...
# 1    https://upload.wikimedia.org/wikipedia/en/thum...
# 2                                                  NaN
# 3    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df = pd.concat([x,y,z])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4309 entries, 0 to 931
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4309 non-null   object
#  1   imdb_id      4309 non-null   object
#  2   poster_path  3560 non-null   object
#  3   wiki_link    4309 non-null   object
#  4   imdb_rating  4296 non-null   float64
#  5   imdb_votes   4296 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 235.6+ KB

# %%
df['imdb_rating'].fillna(value=0,inplace=True)

# %%
df['imdb_votes'].fillna(value=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4309 entries, 0 to 931
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4309 non-null   object
#  1   imdb_id      4309 non-null   object
#  2   poster_path  3560 non-null   object
#  3   wiki_link    4309 non-null   object
#  4   imdb_rating  4309 non-null   float64
#  5   imdb_votes   4309 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 235.6+ KB

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import seaborn as sns

# %%
sns.kdeplot(data=df, x='imdb_rating')
# Out:
# <Axes: xlabel='imdb_rating', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='imdb_votes')
# Out:
# <Axes: xlabel='imdb_votes', ylabel='Density'>

# %%
sns.scatterplot(data=df, x='imdb_votes',y='imdb_rating')
# Out:
# <Axes: xlabel='imdb_votes', ylabel='imdb_rating'>

# %% [markdown]
# # MAIN APPROACH FOR RECOMMENDING POPULAR BASED MOVIES

# %%
"""
    CONSIDERING POPULAR MOVIES AS BET RATE 6 TO 8
    AND VOTES 30000 TO 50000
"""
pass

# %%
df.drop_duplicates(inplace=True)

# %%
popular_movies = df[(df['imdb_rating'] > 6) & ((df['imdb_votes']>= 30000))].sort_values(by=['imdb_votes'], ascending=False)

# %%
popular_movies.shape
# Out:
# (60, 6)

# %% [markdown]
# # CREATING PICKLE FILE

# %%
import pickle

# %%
pickle.dump(popular_movies,open('popular_movies.pkl', 'wb'))

# %% [markdown]
# # POPULAR MOVIES FROM DATASET

# %%
x = list(popular_movies['title'].values)

# %%
x
# Out:
# ['3 Idiots',
#  'Taare Zameen Par',
#  'PK (film)',
#  'Dangal (film)',
#  'Rang De Basanti',
#  'Lagaan',
#  'My Name Is Khan',
#  'Swades',
#  'Gangs of Wasseypur',
#  'Barfi!',
#  'Chak De! India',
#  'Munna Bhai M.B.B.S.',
#  'Bajrangi Bhaijaan',
#  'Dil Chahta Hai',
#  'Zindagi Na Milegi Dobara',
#  'Dilwale Dulhania Le Jayenge',
#  'Kal Ho Naa Ho',
#  'Drishyam (2015 film)',
#  'Queen (2014 film)',
#  'Children of Heaven',
#  'Bhaag Milkha Bhaag',
#  'Kahaani',
#  'Ghajini (2008 film)',
#  'Andhadhun',
#  'Hera Pheri (2000 film)',
#  'Airlift (film)',
#  'Baby (2015 Hindi film)',
#  'Jab Tak Hai Jaan',
#  'Sholay',
#  'Sholay',
#  'Don 2',
#  'Haider (film)',
#  'Special 26',
#  'Andaz Apna Apna',
#  'OMG – Oh My God!',
#  'Veer-Zaara',
#  'Kuch Kuch Hota Hai',
#  'The Lunchbox',
#  'Jab We Met',
#  'Sanju',
#  'Kabhi Khushi Kabhie Gham...',
#  'Rab Ne Bana Di Jodi',
#  'Fan (film)',
#  'Udaan (2010 film)',
#  'Lage Raho Munna Bhai',
#  'Vishwaroopam',
#  'Raees (film)',
# ...

# %%
popular_movies
# Out:
#                                 title    imdb_id  \
# 0                            3 Idiots  tt1187043
# 215                  Taare Zameen Par  tt0986264
# 586                         PK (film)  tt2338151
# 360                     Dangal (film)  tt5074352
# 285                   Rang De Basanti  tt0405508
# 657                            Lagaan  tt0169102
# 849                   My Name Is Khan  tt1188996
# 476                            Swades  tt0367110
# 714                Gangs of Wasseypur  tt1954470
# 729                            Barfi!  tt2082197
# 154                    Chak De! India  tt0871510
# 494               Munna Bhai M.B.B.S.  tt0374887
# 367                 Bajrangi Bhaijaan  tt3863552
# 660                    Dil Chahta Hai  tt0292490
# 798          Zindagi Na Milegi Dobara  tt1562872
# 1058      Dilwale Dulhania Le Jayenge  tt0112870
# 487                     Kal Ho Naa Ho  tt0347304
# 430              Drishyam (2015 film)  tt4430212
# ...
